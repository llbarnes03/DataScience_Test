# %%
import pandas as pd
import csv

# %%
df1 = pd.read_csv("RAW_INCIDENTS.csv", engine='python')
df2 = pd.read_csv("RAW_INCIDENTS_19Oct18.csv", engine='python')
df3 = pd.read_csv("RAW_INCIDENTS_15Dec18.csv", engine='python')

# %%
finaldf = pd.concat([df1, df2, df3], axis=0, ignore_index = True)

# %%
finaldf
# Out:
#             Incident ID       CB-ISEA   Common Name Refined Common Name  \
# 0       INC000003330268  APPLICATIONS          MFOM                MFOM
# 1       INC000003330280  APPLICATIONS          MFOM                MFOM
# 2       INC000001056341  APPLICATIONS         NTCSS               NTCSS
# 3       INC000001376847  APPLICATIONS         NTCSS               NTCSS
# 4       INC000001376869  APPLICATIONS         NTCSS               NTCSS
# 5       INC000001376887  APPLICATIONS         NTCSS               NTCSS
# 6       INC000001838554  APPLICATIONS         NTCSS               NTCSS
# 7       INC000002264454  APPLICATIONS         NTCSS               NTCSS
# 8       INC000002441949  APPLICATIONS         NTCSS               NTCSS
# 9       INC000002442100  APPLICATIONS         NTCSS               NTCSS
# 10      INC000002442211  APPLICATIONS         NTCSS               NTCSS
# 11      INC000002442235  APPLICATIONS         NTCSS               NTCSS
# ...
